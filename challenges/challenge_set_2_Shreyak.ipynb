# %%
import csv
import pandas as pd 
from collections import defaultdict
import dateutil.parser
import re

# %%
with open("turnstyle.txt") as f:
    reader = csv.reader(f)
    next(reader) # skip header
    first_4 = []
    remaining = []
    for row in reader:
        first_4.append(row[0:4])
        remaining.append(row[4:])


z = first_4[0]

# %%
with open("turnstyle.txt") as f:
    reader = csv.reader(f)
    next(reader) # skip header
    
    r1 = []
    for row in reader:
        r1.append(row[6:7])
q = re.findall(r'\[(.*?)\]',values)

# %%
values = ','.join(str(v) for v in r1)
values2 = ','.join(str(v) for v in q)

# %%
 kod = values2.split(',')
kod
# Out:
# ["'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/16/2019'",
#  "'09/16/2019'",
#  "'09/16/2019'",
#  "'09/16/2019'",
#  "'09/16/2019'",
#  "'09/16/2019'",
#  "'09/17/2019'",
#  "'09/17/2019'",
#  "'09/17/2019'",
#  "'09/17/2019'",
#  "'09/17/2019'",
#  "'09/17/2019'",
#  "'09/18/2019'",
#  "'09/18/2019'",
#  "'09/18/2019'",
#  "'09/18/2019'",
#  "'09/18/2019'",
#  "'09/18/2019'",
#  "'09/19/2019'",
#  "'09/19/2019'",
#  "'09/19/2019'",
#  "'09/19/2019'",
#  "'09/19/2019'",
#  "'09/19/2019'",
#  "'09/20/2019'",
#  "'09/20/2019'",
#  "'09/20/2019'",
#  "'09/20/2019'",
#  "'09/20/2019'",
#  "'09/20/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/14/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
#  "'09/15/2019'",
# ...

# %%
with open("turnstyle.txt") as f:
    reader = csv.reader(f)
    next(reader) # skip header
    
    r3 = []
    for row in reader:
        r3.append(row[5:7])

# %%
df = pd.read_csv('turnstyle.txt')
d = df['ENTRIES']
rope = d.tolist()

# %%
p = []
for i in kod:
    p.append(dateutil.parser.parse(i))

# %%
final_list = list(zip(p,rope))

# %%
with open("turnstyle.txt") as f:
    reader = csv.reader(f)
    next(reader) # skip header
    first_4 = []
    remaining = []
    for row in reader:
        first_4.append(row[0:4])
        remaining.append(row[4:])

# %%
plesto2 = {}
z1 = tuple(z)
final_list2 = tuple(final_list)
plesto2[z1]=final_list2

# %%
plesto2
# Out:
# {('A002',
#   'R051',
#   '02-00-00',
#   '59 ST'): ((datetime.datetime(2019, 9, 14, 0, 0),
#    7198818), (datetime.datetime(2019, 9, 14, 0, 0), 7198834), (datetime.datetime(2019, 9, 14, 0, 0),
#    7198847), (datetime.datetime(2019, 9, 14, 0, 0),
#    7198929), (datetime.datetime(2019, 9, 14, 0, 0), 7199125), (datetime.datetime(2019, 9, 14, 0, 0),
#    7199405), (datetime.datetime(2019, 9, 15, 0, 0),
#    7199547), (datetime.datetime(2019, 9, 15, 0, 0), 7199567), (datetime.datetime(2019, 9, 15, 0, 0),
#    7199579), (datetime.datetime(2019, 9, 15, 0, 0),
#    7199648), (datetime.datetime(2019, 9, 15, 0, 0), 7199800), (datetime.datetime(2019, 9, 15, 0, 0),
#    7200012), (datetime.datetime(2019, 9, 16, 0, 0),
#    7200082), (datetime.datetime(2019, 9, 16, 0, 0), 7200086), (datetime.datetime(2019, 9, 16, 0, 0),
#    7200125), (datetime.datetime(2019, 9, 16, 0, 0),
#    7200262), (datetime.datetime(2019, 9, 16, 0, 0), 7200539), (datetime.datetime(2019, 9, 16, 0, 0),
# ...
